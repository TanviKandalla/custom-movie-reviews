# %%
import pandas as pd

# %%
import re
from nltk.util import ngrams
from sklearn.feature_extraction.text import TfidfVectorizer

def summarize_text(dataframe, genres, num_ngrams=10):
    # Filling in NaN values
    if dataframe['review'].isnull().any():
        dataframe['review'] = dataframe['review'].fillna('This abstract does not exist')

    # Concatenate all abstracts into a single text
    combined_text = ' '.join(dataframe['review'])

    # Getting tf-idf tables
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform([combined_text])
    feature_names = vectorizer.get_feature_names()

    # Generating the best summary for the combined text
    abstract = combined_text
    tfidf_scores = tfidf_matrix.toarray().flatten()

    # Sentence Tokenization
    pattern = r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?|\!)\s'
    sentences = re.split(pattern, abstract)
    sentences = [sentence for sentence in sentences if any(char.isalpha() for char in sentence)]

    # N-gram scoring based on tf-idf values
    ngram_scores = {}
    for sentence in sentences:
        words = sentence.split(' ')

        # Generate overlapping n-grams using sliding window
        ngrams_list = []
        window_size = 10
        for i in range(len(words) - window_size + 1):
            ngram = words[i:i + window_size]
            ngrams_list.append(ngram)

        for ngram in ngrams_list:
            tfidf_score = sum(tfidf_scores[vectorizer.vocabulary_.get(word.lower(), -1)] for word in ngram)
            for i in genres:
                if i.lower() in [item.lower() for item in ngram]:
                    tfidf_score += 1.0
            ngram_scores[' '.join(ngram)] = tfidf_score

    # Select top-scoring non-overlapping n-grams
    top_ngrams = []
    for ngram, score in sorted(ngram_scores.items(), key=lambda x: x[1], reverse=True):
        # Check if n-gram contains any words from existing top n-grams
        if not any(word in ' '.join(top_ngrams) for word in ngram.split()):
            top_ngrams.append(ngram)
        if len(top_ngrams) == num_ngrams:
            break

    # Concatenate top n-grams
    summary = ' '.join(top_ngrams)
    return summary

# %%
features = pd.read_csv('fixed_preproc.csv')

# %%
watchlist = pd.read_csv('Final_valid_files.csv')

# %%
paths = ['Evil Dead II 1987',
'Duck Soup 1933',
'Gone Baby Gone 2007',
'WALL·E 2008',
'The Babadook 2014',
'1408 2007',
'Changeling 2008',
'The Lego Movie 2014',
'Draft Day 2014',
'Dunkirk 2017']

# %%
movies = ['Evil Dead II',
'Duck Soup',
'Gone Baby Gone',
'WALL·E',
'The Babadook',
'1408',
'Changeling',
'The Lego Movie',
'Draft Day',
'Dunkirk']

# %%
new_watchlist = watchlist
for i in range(0,len(watchlist['Input'])):
    if watchlist['Input'][i] not in movies:
        new_watchlist = new_watchlist.drop(i, axis = 0)

# %%
new_watchlist = new_watchlist.reset_index()
new_watchlist = new_watchlist.drop('index',axis = 1)

# %%
new_watchlist
# Out:
#                                 Movie 1                Movie 2  \
# 0                              13 Hours             Mr. Nobody
# 1                              13 Hours             Mr. Nobody
# 2                              13 Hours             Mr. Nobody
# 3                                 X-Men          Woman in Gold
# 4                                 X-Men          Woman in Gold
# 5                                 X-Men          Woman in Gold
# 6                                 X-Men          Woman in Gold
# 7                                 X-Men          Woman in Gold
# 8                                 X-Men          Woman in Gold
# 9                                 X-Men          Woman in Gold
# 10                       Kôkaku Kidôtai  To Kill a Mockingbird
# 11                     Bringing Up Baby              Smallfoot
# 12                          Kai po che!     Dallas Buyers Club
# 13                              Amadeus              Fired Up!
# 14  Lock, Stock and Two Smoking Barrels           The Thin Man
# 15                                Sanju         Mildred Pierce
# 16                 To Have and Have Not     The Usual Suspects
# 8                            Deadpool 2         El orfanato       Draft Day
# 9                            Deadpool 2         El orfanato         Dunkirk
# 10                         Bubba Ho-Tep  The Killing Fields  The Lego Movie
# 11  Le charme discret de la bourgeoisie    K.G.F: Chapter 2    Evil Dead II
# 12                                    Z     Wo hu cang long  Gone Baby Gone
# 13                                Nixon              Avatar  The Lego Movie
# 14     What Ever Happened to Baby Jane?          Veer-Zaara         Dunkirk
# 15                                Rango     Le Petit Prince            1408
# 16                   The Sound of Music          Blue Crush         Dunkirk
# 17                          Toy Story 3            The Ring  Gone Baby Gone
#
#                                                Review
# 0   Based on your movie history, you would likely ...
# 1   Yes, you would enjoy Duck Soup. This Marx Brot...
# 2   Yes, I would enjoy Gone Baby Gone based on the...
# 3   Yes, I think you would enjoy watching WALL·E. ...
# 4   Yes, I would enjoy The Babadook based on my hi...
# 5   Yes, I believe you would enjoy 1408, based on ...
# 6   Yes, I would enjoy Changeling. I have watched ...
# 7   Yes, I believe you would enjoy The Lego Movie ...
# 8   Yes, I believe I would enjoy the movie Draft D...
# 9   Yes, based on your movie history, you would en...
# 10  Yes, I think I would enjoy The Lego Movie base...
# 11  Yes, I would enjoy the movie Evil Dead II, bas...
# 12  Based on my history of watching movies, I beli...
# 13  Yes, I believe you would enjoy The Lego Movie ...
# 14  Yes, you would enjoy Dunkirk based on your his...
# 15  Based on the movies you have watched, I would ...
# 16  Yes, you would likely enjoy the movie Dunkirk ...
# 17  Based on your history, you would likely enjoy ...

# %%
def createInputs(watchlist, features, watchlistRow):
    genres = []
    for j in range(1,11):
        col = "Movie "+str(j)
        ind = (features[features['Title'] == watchlist[col][0]].index.tolist())
        temp = []
        for movie in watchlist[col]:
            ind = features[features['Title'] == movie].index.tolist()
            for index in ind:
                genres_str = features.loc[index, 'genres']
                genres_list = [item.strip().strip("\"'") for item in genres_str.strip("[]").split(",")]
                temp.extend(genres_list)
        genres.append(temp)
        
    input_1 = []
    for i in genres:
        for j in i:
            if j not in input_1:
                input_1.append(j)
    return input_1

# %%
def makeSummaries(watchlist, features, movie_list, movie_paths):
    for i in range(0,len(movie_paths)):
        movie_paths[i] = "C:\\Users\\Tanvi Kandalla\\Downloads\\sem_project(2)\\sem_project\\data\\raw\\2_reviews_per_movie_raw\\"+movie_paths[i]+".csv"
    
    summary = []
    for i in range(0,len(watchlist['Input'])):
        inp = createInputs(watchlist, features, i)
        if not isinstance(movie_list,list):
            ind = movie_list.tolist().index(watchlist['Input'][i])
        else:
            ind = movie_list.index(watchlist['Input'][i])
        review = pd.read_csv(movie_paths[ind])
        x = summarize_text(review,inp,10)
        summary.append(x)
        
    return summary

# %%
s = makeSummaries(new_watchlist, features, movies, paths)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
new_watchlist['Summaries'] = s

# %%
new_watchlist
# Out:
#                                 Movie 1                Movie 2  \
# 0                              13 Hours             Mr. Nobody
# 1                              13 Hours             Mr. Nobody
# 2                              13 Hours             Mr. Nobody
# 3                                 X-Men          Woman in Gold
# 4                                 X-Men          Woman in Gold
# 5                                 X-Men          Woman in Gold
# 6                                 X-Men          Woman in Gold
# 7                                 X-Men          Woman in Gold
# 8                                 X-Men          Woman in Gold
# 1                                 Annie     The Jungle Book       Duck Soup
# 2                                 Annie     The Jungle Book  Gone Baby Gone
# 3                            Deadpool 2         El orfanato          WALL·E
# 4                            Deadpool 2         El orfanato    The Babadook
# 5                            Deadpool 2         El orfanato            1408
# 6                            Deadpool 2         El orfanato      Changeling
# 7                            Deadpool 2         El orfanato  The Lego Movie
# 8                            Deadpool 2         El orfanato       Draft Day
# 9                            Deadpool 2         El orfanato         Dunkirk
# 10                         Bubba Ho-Tep  The Killing Fields  The Lego Movie
# 11  Le charme discret de la bourgeoisie    K.G.F: Chapter 2    Evil Dead II
# 12                                    Z     Wo hu cang long  Gone Baby Gone
# 13                                Nixon              Avatar  The Lego Movie
# 14     What Ever Happened to Baby Jane?          Veer-Zaara         Dunkirk
# 15                                Rango     Le Petit Prince            1408
# 16                   The Sound of Music          Blue Crush         Dunkirk
# 17                          Toy Story 3            The Ring  Gone Baby Gone
#
#                                                Review  \
# 0   Based on your movie history, you would likely ...
# 1   Yes, you would enjoy Duck Soup. This Marx Brot...
# 2   Yes, I would enjoy Gone Baby Gone based on the...
# 3   Yes, I think you would enjoy watching WALL·E. ...
# 4   Yes, I would enjoy The Babadook based on my hi...
# 5   Yes, I believe you would enjoy 1408, based on ...
# 6   Yes, I would enjoy Changeling. I have watched ...
# 7   Yes, I believe you would enjoy The Lego Movie ...
# 8   Yes, I believe I would enjoy the movie Draft D...
# 9   Yes, based on your movie history, you would en...
# 10  Yes, I think I would enjoy The Lego Movie base...
# 11  Yes, I would enjoy the movie Evil Dead II, bas...
# 12  Based on my history of watching movies, I beli...
# 13  Yes, I believe you would enjoy The Lego Movie ...
# 14  Yes, you would enjoy Dunkirk based on your his...
# 15  Based on the movies you have watched, I would ...
# 16  Yes, you would likely enjoy the movie Dunkirk ...
# 17  Based on your history, you would likely enjoy ...
#
#                                             Summaries
# 0   the horror of the first film to the comedy of ...
# 1   has the greatest comedy routine in the history...
# 2   movie that contains the kind of action and dra...
# 3   the character development, the special-effects...
# 4   drama to explain the pain of the mother and th...
# 5   him of the dreadful history of the room and th...
# 6   about the history of the corruption of the L.A...
# 7   and so the tension of the drama & action was T...
# 8   to the drama of the last day of the transfer i...
# 9   the action to the British ports, the Channel, ...
# 10  and so the tension of the drama & action was T...
# 11  the horror of the first film to the comedy of ...
# 12  movie that contains the kind of action and dra...
# 13  and so the tension of the drama & action was T...
# 14  the action to the British ports, the Channel, ...
# 15  him of the dreadful history of the room and th...
# 16  the action to the British ports, the Channel, ...
# 17  movie that contains the kind of action and dra...

# %%
from rouge import Rouge
ROUGE = Rouge()
ro = []
for i in range(0,len(new_watchlist['Review'])):
    score = ROUGE.get_scores(new_watchlist['Review'][i], new_watchlist['Summaries'][i])
    p = score[0]["rouge-1"]["p"]
    r = score[0]["rouge-1"]["r"]
    f1 = score[0]["rouge-1"]["f"]
    ro.append([p, r, f1])

# %%
p_sum = 0
t = []
for score in ro:
    p_sum += score[0]
    t.append(score[0])
total = len(ro)
avg = p_sum/total

# %%
print(avg, max(t))
# Out:
# 0.21117941997381723 0.2916666666666667

# %%
new_watchlist.to_csv('summaries_1.csv')
